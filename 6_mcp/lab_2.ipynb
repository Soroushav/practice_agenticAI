# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from agents.mcp import MCPServerStdio
from IPython.display import display, Markdown

load_dotenv(override=True)
# Out:
# True

# %%
normal_agent = Agent(
    name="normal",
    model="gpt-4o-mini",
    instructions="you are a helpful assistant"
)

# %%
prompt = "What time it is now?"
with trace("Normal Test"):
    result = await Runner.run(normal_agent, prompt)
    print(result.final_output)
# Out:
# I’m unable to provide real-time information, including the current time. You can check the time on your device or through a search engine. If you need help with something else, feel free to ask!

# %%
params = {"command": "uv", "args": ["run", "myMCP/time_server.py"]}
async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.session.list_tools()
# Out:
# Error initializing MCP server: Connection closed
# ---------------------------------------------------------------------------
# McpError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 params = {"command": "uv", "args": ["run", "time_server.py"]}
# ----> 2 async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
#       3     mcp_tools = await server.session.list_tools()
#
# File ~/Desktop/projects/practice_agenticAI/.venv/lib/python3.12/site-packages/agents/mcp/server.py:244, in __aenter__(self)
#     243 def invalidate_tools_cache(self):
# --> 244     """Invalidate the tools cache."""
#     245     self._cache_dirty = True
#
# File ~/Desktop/projects/practice_agenticAI/.venv/lib/python3.12/site-packages/agents/mcp/server.py:285, in connect(self)
#     282         await self.cleanup()
#     283         raise
# --> 285 async def list_tools(
#     286     self,
#     287     run_context: RunContextWrapper[Any] | None = None,
#     288     agent: AgentBase | None = None,
#     289 ) -> list[MCPTool]:
#     290     """List the tools available on the server."""
#     291     if not self.session:
#
# File ~/Desktop/projects/practice_agenticAI/.venv/lib/python3.12/site-packages/mcp/client/session.py:171, in initialize(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/projects/practice_agenticAI/.venv/lib/python3.12/site-packages/mcp/shared/session.py:306, in send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     296 async def send_notification(
#     297     self,
#     298     notification: SendNotificationT,
#     299     related_request_id: RequestId | None = None,
#     300 ) -> None:
#     301     """
#     302     Emits a notification, which is a one-way message that does not expect
#     303     a response.
#     304     """
#     305     # Some transport implementations may need to set the related_request_id
# --> 306     # to attribute to the notifications to the request that triggered them.
#     307     jsonrpc_notification = JSONRPCNotification(
#     308         jsonrpc="2.0",
#     309         **notification.model_dump(by_alias=True, mode="json", exclude_none=True),
#     310     )
#     311     session_message = SessionMessage(
#     312         message=JSONRPCMessage(jsonrpc_notification),
#     313         metadata=ServerMessageMetadata(related_request_id=related_request_id) if related_request_id else None,
#     314     )
#
# McpError: Connection closed
